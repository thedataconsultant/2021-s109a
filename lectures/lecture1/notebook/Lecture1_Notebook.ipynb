# %% [markdown]
# # <img style="float: left; padding-right: 10px; width: 45px" src="data:image/png;base64,..."> CS-S109A Introduction to Data Science
#
# ## Lecture 1: Hubway Example
#
#
# **Harvard University**<br/>
# **Summer 2021**<br/>
# **Instructors**: Kevin Rader
#
# ---

# %% [markdown]
# ## If you have not installed Conda and have Jupyter Notebooks running properly on your computer, please see *Lab 0* on the course Canvas website (or on git).

# %%
## RUN THIS CELL TO GET THE RIGHT FORMATTING 
import requests
from IPython.core.display import HTML
styles = requests.get("https://raw.githubusercontent.com/Harvard-IACS/2018-CS109A/master/content/styles/cs109.css").text
HTML(styles)
# Out:
# <style>
# blockquote { background: #AEDE94; }
# h1 {
#     padding-top: 25px;
#     padding-bottom: 25px;
#     text-align: left;
#     padding-left: 10px;
#     background-color: #DDDDDD;
#     color: black;
# }
# h2 {
#     padding-top: 10px;
#     padding-bottom: 10px;
#     text-align: left;
#     padding-left: 5px;
#     background-color: #EEEEEE;
#     color: black;
# }
#
# div.exercise {
# 	background-color: #ffcccc;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# }
#
# div.exercise-r {
# 	background-color: #fce8e8;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# }
#
#
# span.sub-q {
# 	font-weight: bold;
# }
# div.theme {
# 	background-color: #DDDDDD;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# 	font-size: 18pt;
# }
# div.gc {
# 	background-color: #AEDE94;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# 	font-size: 12pt;
# }
# p.q1 {
#     padding-top: 5px;
#     padding-bottom: 5px;
#     text-align: left;
#     padding-left: 5px;
#     background-color: #EEEEEE;
#     color: black;
# }
# header {
#    padding-top: 35px;
#     padding-bottom: 35px;
#     text-align: left;
#     padding-left: 10px;
#     background-color: #DDDDDD;
#     color: black;
# }
# </style>

# %%
import pandas as pd
import sys
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from math import radians, cos, sin, asin, sqrt
import datetime
# %matplotlib inline

# %% [markdown]
# Download the data from (29MB):
#
# https://drive.google.com/open?id=0B28c493CP9GtMzN1emFoMkJNNlU

# %% [markdown]
# ## 1. Data Manipulation & Wrangling
#
# Manipulation, not Modificaition (important distinction).  Fill-in the 3 different 'Your code here' sections below to perform the tasks given.

# %%
# you may need to change the path here:
hubway_data_file = '~/Downloads/hubway_data/hubway_trips.csv'

# read in the data using pandas 'read_csv' funciton
hubway_data = pd.read_csv(hubway_data_file, low_memory=False)

# %%
# use the pd.head command to view the first 5 rows of the data set and pd.tail to print out the last 10 rows
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.head.html


################
# Your code here
################

hubway_data.head()
# Out:
#    seq_id  hubway_id  status  duration          start_date  strt_statn  \
# 0       1          8  Closed         9  7/28/2011 10:12:00        23.0
# 1       2          9  Closed       220  7/28/2011 10:21:00        23.0
# 2       3         10  Closed        56  7/28/2011 10:33:00        23.0
# 3       4         11  Closed        64  7/28/2011 10:35:00        23.0
# 4       5         12  Closed        12  7/28/2011 10:37:00        23.0
#
#              end_date  end_statn bike_nr  subsc_type zip_code  birth_date  \
# 0  7/28/2011 10:12:00       23.0  B00468  Registered   '97217      1976.0
# 1  7/28/2011 10:25:00       23.0  B00554  Registered   '02215      1966.0
# 2  7/28/2011 10:34:00       23.0  B00456  Registered   '02108      1943.0
# 3  7/28/2011 10:36:00       23.0  B00554  Registered   '02116      1981.0
# 4  7/28/2011 10:37:00       23.0  B00554  Registered   '97214      1983.0
#
#    gender
# 0    Male
# 1    Male
# 2    Male
# 3  Female
# 4  Female

# %%
# determine the size and dimensions of the data frame using df.size and df.shape 
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.shape.html
# pull off the column and row names using df.columns and df.index.values

################
# Your code here
################
print("Data size:", hubway_data.size) 
print("Data shape:", hubway_data.shape)
# Out:
# Data size: 20527325
# Data shape: (1579025, 13)

# %%
# pull off the first 2 entries of the gender variable:

print(hubway_data['gender'][0:2])

# the ever important 'values' command: this converts a pandas object 
# to a numpy array.  We'll learn more about this next time.

print(hubway_data['gender'][0:2].values)
# Out:
# 0    Male
# 1    Male
# Name: gender, dtype: object
# ['Male' 'Male']

# %%
# processing the checkout dates a little 

print(hubway_data['start_date'][0])

# pull off the hour into 'checkout_hour'
checkout_hour = hubway_data['start_date'].apply(lambda s: int(s[-8:-6]))
print(checkout_hour[0:3])

# create 'checkout_year' to pull of the year of the checkout start time.

################
# Your code here
################

checkout_year = hubway_data['start_date'].apply(lambda s: int(s[-13:-9]))
print(checkout_year[0:3])
# Out:
# 7/28/2011 10:12:00
# 0    10
# 1    10
# 2    10
# Name: start_date, dtype: int64
# 0    2011
# 1    2011
# 2    2011
# Name: start_date, dtype: int64

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Data Exploration
# ### Who?
#
# Use the data frame to explore the distributions of user type, gender, and age (4 'Your code here' fill-ins).

# %%
# create a table, a barplot, and pie chart of subscriber type: 'subsc_type'

# 2 ways to do the same thing:
subsc_counts = np.unique(hubway_data['subsc_type'], return_counts=True)
print(subsc_counts)

print(np.unique(hubway_data.subsc_type,return_counts=True))

# now for the barplot
plt.bar(subsc_counts[0],subsc_counts[1])
plt.show()
# Out:
# (array(['Casual', 'Registered'], dtype=object), array([ 472611, 1106414]))
# (array(['Casual', 'Registered'], dtype=object), array([ 472611, 1106414]))

# %%
# Create a table of counts for each gender in the checkout data set 
# Use this table to create a bar plot of gender 
# Hint: use .dropna() on the relevant variable


################
# Your code here
################

gender = hubway_data['gender'].dropna()
gender_counts = np.unique(gender, return_counts=True)

plt.bar(gender_counts[0], gender_counts[1])
plt.show()

# %%
hubway_data.head()
# Out:
#    seq_id  hubway_id  status  duration          start_date  strt_statn  \
# 0       1          8  Closed         9  7/28/2011 10:12:00        23.0
# 1       2          9  Closed       220  7/28/2011 10:21:00        23.0
# 2       3         10  Closed        56  7/28/2011 10:33:00        23.0
# 3       4         11  Closed        64  7/28/2011 10:35:00        23.0
# 4       5         12  Closed        12  7/28/2011 10:37:00        23.0
#
#              end_date  end_statn bike_nr  subsc_type zip_code  birth_date  \
# 0  7/28/2011 10:12:00       23.0  B00468  Registered   '97217      1976.0
# 1  7/28/2011 10:25:00       23.0  B00554  Registered   '02215      1966.0
# 2  7/28/2011 10:34:00       23.0  B00456  Registered   '02108      1943.0
# 3  7/28/2011 10:36:00       23.0  B00554  Registered   '02116      1981.0
# 4  7/28/2011 10:37:00       23.0  B00554  Registered   '97214      1983.0
#
#    gender
# 0    Male
# 1    Male
# 2    Male
# 3  Female
# 4  Female

# %%
# create a variable 'age' outside the data frame for the ages of users (use 'checkout_year').  
# Then add the variable into the data frame  

################
# Your code here
################

age = checkout_year - hubway_data['birth_date']


# calculate mean, median, sd, min, and max of the ages of hubway users
# be careful handling nan's in np.median (.dropna() may be helpful)

################
# Your code here
################

print("Mean age:", age.mean())
print("Median age:", age.median())
print("Standard deviation age:", np.std(age.dropna()))
print("Min age:", age.min())
print("Max age:", age.max())



# Create the default histogram of age using plt.hist.  
# Then improve the histogram with bins of 15-19, 20-24, etc. and improved labels
# plt.xlabel, plt.ylabel, and plt.title will be useful

################
# Your code here
################
plt.hist(age, bins = list(range(15, 85, 5)))
plt.xlabel("Ages"); 
plt.title("Histogram of ages among Hubway data");
# Out:
# Mean age: 35.48022780940213
# Median age: 32.0
# Standard deviation age: 10.988319684159583
# Min age: 17.0
# Max age: 79.0

# %% [markdown]
# ## 3. Interpretation Questions:
#
# 1. Use summary statistics and the histogram above to describe the distribution of user ages in the data set.
#
# 2. What is wrong with the statement "The average age of Hubway bike share users is roughly 35.5 years old"?.
#
# 3. What would be a better interpretation of the mean age of the users calcualted here?

# %% [markdown]
# 1. The distribution of user ages is right skewed, meaning there are a mass of users around the 20-40 range and dips off in the greater ranges.
#
# 2. Because it's right skewed, it might not necessarily be the best to use the mean as the "average"
#
# 3. Probably the median

# %% [markdown]
# ## 4. More Visualizations
#
# Look at creating subfigures and exploring the usage across location (distance from Boston 'center city').

# %%
hubway_data.head()
# Out:
#    seq_id  hubway_id  status  duration          start_date  strt_statn  \
# 0       1          8  Closed         9  7/28/2011 10:12:00        23.0
# 1       2          9  Closed       220  7/28/2011 10:21:00        23.0
# 2       3         10  Closed        56  7/28/2011 10:33:00        23.0
# 3       4         11  Closed        64  7/28/2011 10:35:00        23.0
# 4       5         12  Closed        12  7/28/2011 10:37:00        23.0
#
#              end_date  end_statn bike_nr  subsc_type zip_code  birth_date  \
# 0  7/28/2011 10:12:00       23.0  B00468  Registered   '97217      1976.0
# 1  7/28/2011 10:25:00       23.0  B00554  Registered   '02215      1966.0
# 2  7/28/2011 10:34:00       23.0  B00456  Registered   '02108      1943.0
# 3  7/28/2011 10:36:00       23.0  B00554  Registered   '02116      1981.0
# 4  7/28/2011 10:37:00       23.0  B00554  Registered   '97214      1983.0
#
#    gender
# 0    Male
# 1    Male
# 2    Male
# 3  Female
# 4  Female

# %%
# subplots: put both the barplot of gender and histogram of time into the same figure

fig, ax = plt.subplots(1, 2, figsize=(15, 6))


# use ax[0].bar to put the barplot in the first subplot 


################
# Your code here
################
ax[0].bar(gender_counts[0], gender_counts[1])


################
# Your code here
################
ax[1].hist(age);

plt.tight_layout()
# Out:
# /anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# ### Where

# %%
# read in the separate station data

station_data = pd.read_csv('~/Downloads/hubway_data/hubway_stations.csv', low_memory=False)[['station','id', 'lat', 'lng']]
station_data.head()
# Out:
#                               station  id        lat        lng
# 0              Colleges of the Fenway   3  42.340021 -71.100812
# 1         Tremont St. at Berkeley St.   4  42.345392 -71.069616
# 2  Northeastern U / North Parking Lot   5  42.341814 -71.090179
# 3            Cambridge St. at Joy St.   6  42.361285 -71.065140
# 4                            Fan Pier   7  42.353412 -71.044624

# %%
hubway_data.head()
# Out:
#    seq_id  hubway_id  status  duration          start_date  strt_statn  \
# 0       1          8  Closed         9  7/28/2011 10:12:00        23.0
# 1       2          9  Closed       220  7/28/2011 10:21:00        23.0
# 2       3         10  Closed        56  7/28/2011 10:33:00        23.0
# 3       4         11  Closed        64  7/28/2011 10:35:00        23.0
# 4       5         12  Closed        12  7/28/2011 10:37:00        23.0
#
#              end_date  end_statn bike_nr  subsc_type zip_code  birth_date  \
# 0  7/28/2011 10:12:00       23.0  B00468  Registered   '97217      1976.0
# 1  7/28/2011 10:25:00       23.0  B00554  Registered   '02215      1966.0
# 2  7/28/2011 10:34:00       23.0  B00456  Registered   '02108      1943.0
# 3  7/28/2011 10:36:00       23.0  B00554  Registered   '02116      1981.0
# 4  7/28/2011 10:37:00       23.0  B00554  Registered   '97214      1983.0
#
#    gender
# 0    Male
# 1    Male
# 2    Male
# 3  Female
# 4  Female

# %%
# join the two together data

hubway_data_with_gps = hubway_data.join(station_data.set_index('id'), on='strt_statn')
hubway_data_with_gps.head()
# Out:
#    seq_id  hubway_id  status  duration          start_date  strt_statn  \
# 0       1          8  Closed         9  7/28/2011 10:12:00        23.0
# 1       2          9  Closed       220  7/28/2011 10:21:00        23.0
# 2       3         10  Closed        56  7/28/2011 10:33:00        23.0
# 3       4         11  Closed        64  7/28/2011 10:35:00        23.0
# 4       5         12  Closed        12  7/28/2011 10:37:00        23.0
#
#              end_date  end_statn bike_nr  subsc_type zip_code  birth_date  \
# 0  7/28/2011 10:12:00       23.0  B00468  Registered   '97217      1976.0
# 1  7/28/2011 10:25:00       23.0  B00554  Registered   '02215      1966.0
# 2  7/28/2011 10:34:00       23.0  B00456  Registered   '02108      1943.0
# 3  7/28/2011 10:36:00       23.0  B00554  Registered   '02116      1981.0
# 4  7/28/2011 10:37:00       23.0  B00554  Registered   '97214      1983.0
#
#    gender                                     station        lat        lng
# 0    Male  Mayor Thomas M. Menino - Government Center  42.359677 -71.059364
# 1    Male  Mayor Thomas M. Menino - Government Center  42.359677 -71.059364
# 2    Male  Mayor Thomas M. Menino - Government Center  42.359677 -71.059364
# 3  Female  Mayor Thomas M. Menino - Government Center  42.359677 -71.059364
# 4  Female  Mayor Thomas M. Menino - Government Center  42.359677 -71.059364

# %%
# determine the number of checkouts at each station, and add 'checkouts' to the 'station_data' data frame
# Hint: use .dropna() on the relevant variable

################
# Your code here
################
station_counts = np.unique(hubway_data_with_gps['strt_statn'].dropna(), return_counts=True)
checkouts_df = pd.DataFrame(station_counts[1], index = station_counts[0], columns = ['checkouts'])

station_data = station_data.join(checkouts_df, on = 'id')

# %%
station_data.head()
# Out:
#                               station  id        lat        lng  checkouts
# 0              Colleges of the Fenway   3  42.340021 -71.100812       9734
# 1         Tremont St. at Berkeley St.   4  42.345392 -71.069616      18058
# 2  Northeastern U / North Parking Lot   5  42.341814 -71.090179      10630
# 3            Cambridge St. at Joy St.   6  42.361285 -71.065140      23322
# 4                            Fan Pier   7  42.353412 -71.044624       9163

# %% [markdown]
# ![Alt](../fig/Lecture1a_g2.png)

# %%
# a user-defined function to calculate distances 'as the crow flies'

def haversine(pt, lat2=42.3604, lon2=-71.05868):
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    Center City (of Boston) is the default comparison point
    """
    lon1 = pt[0]
    lat1 = pt[1]
    
    # convert decimal degrees to radians 
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])

    # haversine formula 
    dlon = lon2 - lon1 
    dlat = lat2 - lat1 
    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 3958.8 # Radius of earth in miles
    return c * r

# %%
# using the hersine function to create 'dist_to_center' variable 
dist_to_center = list(map(haversine, station_data[['lng', 'lat']].values))

# add 'dist_to_center' to the 'station_data' data frame

################
# Your code here 
################

station_data['dist_to_center'] = dist_to_center

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))

# use ax.scatter to create a scatter plot of x = 'dist_to_center' and y = 'checkouts'

################
# Your code here
################

plt.scatter(station_data['dist_to_center'], station_data['checkouts'])

# plt.show

# %% [markdown]
# ### When...this is done for you

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 5))

# tabulating the hour of the day that users checkout the bikes

checkout_counts = np.unique(checkout_hour, return_counts=True)
plt.bar(checkout_counts[0], checkout_counts[1], align='center', width=0.8, alpha=0.6)
ax.set_xlim([-1, 24])
ax.set_xticks(range(24))
ax.set_xlabel('Hour of Day')
ax.set_ylabel('Number of Checkouts')
ax.set_title('Time of Day vs Checkouts')

plt.show()

# %% [markdown]
# ## 5. More Interpretations
#
# 1. What do you notice in the scatterplot of checkouts vs. distance above?  What does this say about useage of the system, in general?
#
# 2. What type of figre is the above plot titled 'Time of Day vs Checkouts'?  Describe what you notice in it.  Why does this make sense?
#
# 3. How can Hubway use this information to improve their systems?
#
# *your answer here*

# %% [markdown]
# ## 6. Further Investigations:
#
# Explore the data to investigate three questions:
#
# 1. Which station is most popular (for check-outs)?
#
# 2. How long does it take to bike from 'Harvard Square at Mass Ave/ Dunster' (closest stop to Harvard Square center) to 'South Station - 700 Atlantic Ave.' (to catch a train)?
#
# 3. What are noticeable differences between Registered and Casual users?  Consider variables we've already looked at or created.

# %%
# answering #1: Which station is most popular (for check-outs)?

################
# Your code here
################
hubway_data_with_gps.head()

b
# Out:
#    seq_id  hubway_id  status  duration          start_date  strt_statn  \
# 0       1          8  Closed         9  7/28/2011 10:12:00        23.0
# 1       2          9  Closed       220  7/28/2011 10:21:00        23.0
# 2       3         10  Closed        56  7/28/2011 10:33:00        23.0
# 3       4         11  Closed        64  7/28/2011 10:35:00        23.0
# 4       5         12  Closed        12  7/28/2011 10:37:00        23.0
#
#              end_date  end_statn bike_nr  subsc_type zip_code  birth_date  \
# 0  7/28/2011 10:12:00       23.0  B00468  Registered   '97217      1976.0
# 1  7/28/2011 10:25:00       23.0  B00554  Registered   '02215      1966.0
# 2  7/28/2011 10:34:00       23.0  B00456  Registered   '02108      1943.0
# 3  7/28/2011 10:36:00       23.0  B00554  Registered   '02116      1981.0
# 4  7/28/2011 10:37:00       23.0  B00554  Registered   '97214      1983.0
#
#    gender                                     station        lat        lng
# 0    Male  Mayor Thomas M. Menino - Government Center  42.359677 -71.059364
# 1    Male  Mayor Thomas M. Menino - Government Center  42.359677 -71.059364
# 2    Male  Mayor Thomas M. Menino - Government Center  42.359677 -71.059364
# 3  Female  Mayor Thomas M. Menino - Government Center  42.359677 -71.059364
# 4  Female  Mayor Thomas M. Menino - Government Center  42.359677 -71.059364

# %%
station_data[station_data['station'] == 'South Station - 700 Atlantic Ave.']
# Out:
#                               station  id        lat        lng  checkouts  \
# 19  South Station - 700 Atlantic Ave.  22  42.352175 -71.055547      56443
#
#     dist_to_center
# 19        0.590384

# %%
harv_square_start = hubway_data_with_gps[hubway_data_with_gps['station'] == 'Harvard Square at Mass Ave/ Dunster']

# %%
harv_square_start_south_station_end = harv_square_start[harv_square_start['end_statn'] == 22.0]

# %%
harv_square_start_south_station_end['minutes'] = harv_square_start_south_station_end['duration'] / 60
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
harv_square_start_south_station_end
# Out:
#           seq_id  hubway_id  status  duration           start_date  \
# 378479    378480     428104  Closed      1512   7/31/2012 13:19:00
# 393588    393589     445209  Closed      3050    8/6/2012 19:07:00
# 394348    394349     446063  Closed      1567    8/7/2012 07:47:00
# 398876    398877     451266  Closed      2711    8/8/2012 16:59:00
# 405683    405684     458874  Closed      6456   8/11/2012 13:01:00
# 405691    405692     458882  Closed      6326   8/11/2012 13:02:00
# 417486    417487     472452  Closed      2000   8/15/2012 17:39:00
# 430231    430232     487068  Closed      5540   8/20/2012 13:52:00
# 430232    430233     487069  Closed      7564   8/20/2012 13:52:00
# 441967    441968     500156  Closed      1627   8/24/2012 08:34:00
# 445831    445832     504502  Closed      8432   8/25/2012 13:30:00
# 445850    445851     504522  Closed      8269   8/25/2012 13:33:00
# 445854    445855     504526  Closed      8265   8/25/2012 13:33:00
# 445857    445858     504531  Closed      8246   8/25/2012 13:33:00
# 478000    478001     540260  Closed      2647    9/6/2012 08:19:00
# 480285    480286     542795  Closed      1415    9/6/2012 19:34:00
# 498617    498618     563505  Closed      1710   9/13/2012 07:51:00
# 581434    581435     656862  Closed      1800  10/13/2012 16:06:00
# 583672    583673     659382  Closed      1260  10/15/2012 04:37:00
# 591657    591658     668353  Closed      2520  10/17/2012 18:33:00
# 603370    603371     681848  Closed     19080  10/21/2012 18:29:00
# 603373    603374     681851  Closed      2700  10/21/2012 18:30:00
# 614173    614174     693964  Closed      1680  10/25/2012 14:05:00
# 733235    733236     830621  Closed      5040   4/29/2013 13:02:00
# 733237    733238     830623  Closed      4980   4/29/2013 13:03:00
# 745244    745245     844270  Closed      1500    5/3/2013 08:05:00
# 775270    775271     878863  Closed      1920   5/12/2013 21:59:00
# 786104    786105     891015  Closed      1500   5/16/2013 08:36:00
# 917688    917689    1038233  Closed      3300   6/23/2013 20:05:00
# 995534    995535    1124112  Closed      4440   7/12/2013 19:01:00
# 995539    995540    1124117  Closed      4380   7/12/2013 19:01:00
# 998227    998228    1127088  Closed      1860   7/13/2013 14:06:00
# 998232    998233    1127093  Closed      1860   7/13/2013 14:06:00
# 1014947  1014948    1145335  Closed      1500   7/17/2013 08:00:00
# 1034785  1034786    1166899  Closed      1500   7/21/2013 17:25:00
# 1174300  1174301    1317474  Closed      2220   8/20/2013 22:09:00
# 1215787  1215788    1361563  Closed      1560   8/29/2013 14:16:00
# 1220748  1220749    1366797  Closed      1740   8/30/2013 14:41:00
# 1259050  1259051    1407807  Closed      4440    9/8/2013 13:50:00
# 1302599  1302600    1454313  Closed      2160   9/17/2013 17:35:00
# 1319180  1319181    1472071  Closed      2280   9/20/2013 18:06:00
# 1423398  1423399    1583437  Closed      4680  10/13/2013 12:15:00
# 1423405  1423406    1583444  Closed      4680  10/13/2013 12:15:00
# 1502441  1502442    1667289  Closed      1740  10/31/2013 03:13:00
# 1505518  1505519    1670525  Closed      4620  10/31/2013 18:28:00
# 1513693  1513694    1679357  Closed      3060   11/2/2013 16:48:00
# 1549597  1549598    1717136  Closed      1680  11/14/2013 15:37:00
# 1549598  1549599    1717137  Closed      1620  11/14/2013 15:38:00
#
#          strt_statn             end_date  end_statn bike_nr  subsc_type  \
# 378479         74.0   7/31/2012 13:44:00       22.0  B00604      Casual
# 393588         74.0    8/6/2012 19:58:00       22.0  B00156      Casual
# 394348         74.0    8/7/2012 08:13:00       22.0  B00167  Registered
# 398876         74.0    8/8/2012 17:44:00       22.0  T01135  Registered
# 405683         74.0   8/11/2012 14:49:00       22.0  B00363      Casual
# 405691         74.0   8/11/2012 14:48:00       22.0  B00410      Casual
# 417486         74.0   8/15/2012 18:12:00       22.0  T01211  Registered
# 430231         74.0   8/20/2012 15:24:00       22.0  B00077      Casual
# 430232         74.0   8/20/2012 15:58:00       22.0  B00615      Casual
# 441967         74.0   8/24/2012 09:02:00       22.0  T01334      Casual
# 445831         74.0   8/25/2012 15:51:00       22.0  B00192      Casual
# 445850         74.0   8/25/2012 15:51:00       22.0  B00468      Casual
# 445854         74.0   8/25/2012 15:51:00       22.0  T01257      Casual
# 445857         74.0   8/25/2012 15:51:00       22.0  T01364      Casual
# 478000         74.0    9/6/2012 09:04:00       22.0  T01007      Casual
# 480285         74.0    9/6/2012 19:57:00       22.0  B00144      Casual
# 498617         74.0   9/13/2012 08:20:00       22.0  B00359  Registered
# 581434         74.0  10/13/2012 16:36:00       22.0  T01347  Registered
# 583672         74.0  10/15/2012 04:58:00       22.0  B00397      Casual
# 591657         74.0  10/17/2012 19:15:00       22.0  T01110      Casual
# 603370         74.0  10/21/2012 23:47:00       22.0  T01450      Casual
# 603373         74.0  10/21/2012 19:15:00       22.0  B00245      Casual
# 614173         74.0  10/25/2012 14:33:00       22.0  T01354  Registered
# 733235         74.0   4/29/2013 14:26:00       22.0  B00056      Casual
# 733237         74.0   4/29/2013 14:26:00       22.0  B00552      Casual
# 745244         74.0    5/3/2013 08:30:00       22.0  T01423  Registered
# 775270         74.0   5/12/2013 22:31:00       22.0  T01370      Casual
# 786104         74.0   5/16/2013 09:01:00       22.0  T01365  Registered
# 917688         74.0   6/23/2013 21:00:00       22.0  B00499      Casual
# 995534         74.0   7/12/2013 20:15:00       22.0  T01320      Casual
# 995539         74.0   7/12/2013 20:14:00       22.0  B00564      Casual
# 998227         74.0   7/13/2013 14:37:00       22.0  T01237      Casual
# 998232         74.0   7/13/2013 14:37:00       22.0  B00419      Casual
# 1014947        74.0   7/17/2013 08:25:00       22.0  T01167  Registered
# 1034785        74.0   7/21/2013 17:50:00       22.0  T01399      Casual
# 1174300        74.0   8/20/2013 22:46:00       22.0  B00335      Casual
# 1215787        74.0   8/29/2013 14:42:00       22.0  T01006  Registered
# 1220748        74.0   8/30/2013 15:10:00       22.0  B00612  Registered
# 1259050        74.0    9/8/2013 15:04:00       22.0  B00588      Casual
# 1302599        74.0   9/17/2013 18:11:00       22.0  B00175  Registered
# 1319180        74.0   9/20/2013 18:44:00       22.0  T01349  Registered
# 1423398        74.0  10/13/2013 13:33:00       22.0  B01474      Casual
# 1423405        74.0  10/13/2013 13:33:00       22.0  A07807      Casual
# 1502441        74.0  10/31/2013 03:42:00       22.0  B00176      Casual
# 1505518        74.0  10/31/2013 19:45:00       22.0  B01485      Casual
# 1513693        74.0   11/2/2013 17:39:00       22.0  T01214      Casual
# 1549597        74.0  11/14/2013 16:05:00       22.0  T01356      Casual
# 1549598        74.0  11/14/2013 16:05:00       22.0  T01439      Casual
#
#         zip_code  birth_date gender                              station  \
# 378479       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 393588       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 394348    '01720      1950.0   Male  Harvard Square at Mass Ave/ Dunster
# 398876    '01475      1974.0   Male  Harvard Square at Mass Ave/ Dunster
# 405683       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 405691       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 417486    '02025      1965.0   Male  Harvard Square at Mass Ave/ Dunster
# 430231       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 430232       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 441967       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 445831       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 445850       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 445854       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 445857       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 478000       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 480285       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 498617    '01720      1950.0   Male  Harvard Square at Mass Ave/ Dunster
# 581434    '02138         NaN   Male  Harvard Square at Mass Ave/ Dunster
# 583672       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 591657       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 603370       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 603373       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 614173    '02114         NaN   Male  Harvard Square at Mass Ave/ Dunster
# 733235       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 733237       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 745244    '02144         NaN   Male  Harvard Square at Mass Ave/ Dunster
# 775270       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 786104    '02138         NaN   Male  Harvard Square at Mass Ave/ Dunster
# 917688       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 995534       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 995539       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 998227       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 998232       NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 1014947   '02144         NaN   Male  Harvard Square at Mass Ave/ Dunster
# 1034785      NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 1174300      NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 1215787   '02478         NaN   Male  Harvard Square at Mass Ave/ Dunster
# 1220748   '02116         NaN   Male  Harvard Square at Mass Ave/ Dunster
# 1259050      NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 1302599   '02478         NaN   Male  Harvard Square at Mass Ave/ Dunster
# 1319180   '02138         NaN   Male  Harvard Square at Mass Ave/ Dunster
# 1423398      NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 1423405   '02111         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 1502441      NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 1505518      NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 1513693      NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 1549597      NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
# 1549598      NaN         NaN    NaN  Harvard Square at Mass Ave/ Dunster
#
#                lat        lng     minutes
# 378479   42.373268 -71.118579   25.200000
# 393588   42.373268 -71.118579   50.833333
# 394348   42.373268 -71.118579   26.116667
# 398876   42.373268 -71.118579   45.183333
# 405683   42.373268 -71.118579  107.600000
# 405691   42.373268 -71.118579  105.433333
# 417486   42.373268 -71.118579   33.333333
# 430231   42.373268 -71.118579   92.333333
# 430232   42.373268 -71.118579  126.066667
# 441967   42.373268 -71.118579   27.116667
# 445831   42.373268 -71.118579  140.533333
# 445850   42.373268 -71.118579  137.816667
# 445854   42.373268 -71.118579  137.750000
# 445857   42.373268 -71.118579  137.433333
# 478000   42.373268 -71.118579   44.116667
# 480285   42.373268 -71.118579   23.583333
# 498617   42.373268 -71.118579   28.500000
# 581434   42.373268 -71.118579   30.000000
# 583672   42.373268 -71.118579   21.000000
# 591657   42.373268 -71.118579   42.000000
# 603370   42.373268 -71.118579  318.000000
# 603373   42.373268 -71.118579   45.000000
# 614173   42.373268 -71.118579   28.000000
# 733235   42.373268 -71.118579   84.000000
# 733237   42.373268 -71.118579   83.000000
# 745244   42.373268 -71.118579   25.000000
# 775270   42.373268 -71.118579   32.000000
# 786104   42.373268 -71.118579   25.000000
# 917688   42.373268 -71.118579   55.000000
# 995534   42.373268 -71.118579   74.000000
# 995539   42.373268 -71.118579   73.000000
# 998227   42.373268 -71.118579   31.000000
# 998232   42.373268 -71.118579   31.000000
# 1014947  42.373268 -71.118579   25.000000
# 1034785  42.373268 -71.118579   25.000000
# 1174300  42.373268 -71.118579   37.000000
# 1215787  42.373268 -71.118579   26.000000
# 1220748  42.373268 -71.118579   29.000000
# 1259050  42.373268 -71.118579   74.000000
# 1302599  42.373268 -71.118579   36.000000
# 1319180  42.373268 -71.118579   38.000000
# 1423398  42.373268 -71.118579   78.000000
# 1423405  42.373268 -71.118579   78.000000
# 1502441  42.373268 -71.118579   29.000000
# 1505518  42.373268 -71.118579   77.000000
# 1513693  42.373268 -71.118579   51.000000
# 1549597  42.373268 -71.118579   28.000000
# 1549598  42.373268 -71.118579   27.000000

# %%
plt.hist(harv_square_start_south_station_end['minutes']);

# %%
# answering #2 :  How long does it take to bike from 'Harvard Square at Mass Ave/ Dunster' 
# (closest stop to Harvard Square center) to 'South Station - 700 Atlantic Ave.' (to catch a train)?

harvard_id = station_data['id'][station_data['station']=='Harvard Square at Mass Ave/ Dunster']

################
# Your code here
################

# %%
# answering #3 What are noticeable differences between Registered and Casual users?  
# Consider variables we've already looked at or created.

################
# Your code here
################

registered = np.unique(checkout_hour[hubway_data['subsc_type']=='Registered'], return_counts=True)
casual = np.unique(checkout_hour[hubway_data['subsc_type']=='Casual'], return_counts=True)

plt.bar(registered[0], registered[1], label = "Registered")
plt.bar(casual[0], casual[1], label = "Casual")
plt.legend()

# %% [markdown]
# *your answer here*
